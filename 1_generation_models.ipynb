# %% [markdown]
# # Fine tuning Generation Models
# Exploring a two-step approach for fine tuning generative LLMs

# %%
# %%capture
# !pip install -q accelerate==0.31.0 peft==0.11.1 bitsandbytes==0.43.1 transformers==4.41.2 trl==0.9.4 sentencepiece==0.2.0 triton==3.1.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.6/251.6 kB 19.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 78.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 76.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 603.5 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 22.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 530.3 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 63.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.0/129.0 kB 6.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.5.1 which is incompatible.
# torchvision 0.21.0+cu124 requires torch==2.6.0, but you have torch 2.5.1 which is incompatible.

# %% [markdown]
# ## Supervised Fine-Tuning (SFT)

# %% [markdown]
# ### Data Preprocessing

# %%
from transformers import AutoTokenizer
from datasets import load_dataset

# load tokenizer to use its chat template
template_tokenizer = AutoTokenizer.from_pretrained("TinyLlama/TinyLlama-1.1B-Chat-v1.0")

def format_prompt(example):
  """Fromat the prompt to using the <|user|> template TinyLLama is using"""

  # format answers
  chat = example["messages"]
  prompt = template_tokenizer.apply_chat_template(chat, tokenize=False)

  return {"text": prompt}

# Load and format the data using the template TinyLLama is using
dataset = (
    load_dataset("HuggingFaceH4/ultrachat_200k", split="test_sft")
      .shuffle(seed=42)
      .select(range(3_000))
)
dataset = dataset.map(format_prompt)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# data/train_sft-00000-of-00003-a3ecf92756(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_sft-00001-of-00003-0a1804bcb6(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_sft-00002-of-00003-ee46ed25cf(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/test_sft-00000-of-00001-f7dfac4afe5(…):   0%|          | 0.00/81.2M [00:00<?, ?B/s]
# data/train_gen-00000-of-00003-a6c9fb894b(…):   0%|          | 0.00/244M [00:00<?, ?B/s]
# data/train_gen-00001-of-00003-d6a0402e41(…):   0%|          | 0.00/243M [00:00<?, ?B/s]
# data/train_gen-00002-of-00003-c0db75b92a(…):   0%|          | 0.00/243M [00:00<?, ?B/s]
# data/test_gen-00000-of-00001-3d4cd830914(…):   0%|          | 0.00/80.4M [00:00<?, ?B/s]
# Generating train_sft split:   0%|          | 0/207865 [00:00<?, ? examples/s]
# Generating test_sft split:   0%|          | 0/23110 [00:00<?, ? examples/s]
# Generating train_gen split:   0%|          | 0/256032 [00:00<?, ? examples/s]
# Generating test_gen split:   0%|          | 0/28304 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3000 [00:00<?, ? examples/s]

# %%
# Example of formatted prompt
print(dataset["text"][2999])
# Out:
# <|user|>
# Can you summarize the main ideas and key figures discussed in the speech on India's Independence Day?
# Generate according to: Speech on Independence Day - 15th August Independence Day Speech in English.
# All of my respected teachers, parents and dear friends greet you all to my Today we have gathered today to celebrate this great national occasion. I wish you all a hearty compliment of 72th Independence Day.
# Today we are a day of pride for all Indians, because we were liberated today and we got rid of the British Raj. Today is a very important day for all Indian citizens. And it has been mentioned forever in history. 15 August 1947 is a historical day which reminds us of our freedom, reminds us of the patriots who gave their home, family, and their lives for their lives. The sacrifices of these patriots to their country were not useless, due to their struggle, on 15 August 1947 their motherland got independence from British rule and since then India's own.
# Today is a very important day for all Indians, whom we celebrate to remember the sacrifices of great Indian leaders, who gave their lives for the country's freedom and prosperity. Independence of India could be possible because cooperation, sacrifice and participation of all Indians was possible. We must give importance and salute to all those Indian citizens because they were the real national heroes of the country.
# Some of the great freedom fighters of India are Netaji Subhash Chandra Bose, Bal Gangadhar Tilak, Chandrasekhar Azad, Mahatma Gandhiji, Jawaharlal Nehru, Khudiram Bose, Bhagat Singh, Lala Lajpat Rai, Ashfaq Ulla Khan, Ram Prasad Bismil etc. These were all great patriots who, without regard to their own lives, fought hard for India's independence. Who struggled hard for India's independence by the end of his life. We can not even imagine those horrific moments of struggle done by our ancestors.
# Even after so many years of independence, our country is on the right track of development. Today our country is well established in the whole world as a democratic country.
# From 1947 till today we are celebrating with great enthusiasm and happiness. On this day, national flag is hoisted at all schools, government offices, national anthem is sung and tribute to all these great men and martyrs who have made many efforts for independence and sweets are distributed on this occasion.
# Our Prime Minister hoisted the national flag on the Red Fort in our capital Delhi. There, this festival is celebrated with great fanfare and splendor. All the martyrs are paid tribute. The Prime Minister conveys the name of the nation and many meetings and programs are organized. We must be proud to be Indian and should make our best contribution to safeguard our country's respect.
# This is the beauty of Hindus !!</s>
# <|assistant|>
# The speech on India's Independence Day highlights the importance of this national occasion, emphasizing the sacrifices of Indian patriots and leaders who fought for India's freedom from British rule. The key figures mentioned include Netaji Subhash Chandra Bose, Bal Gangadhar Tilak, Chandrasekhar Azad, Mahatma Gandhi, Jawaharlal Nehru, Khudiram Bose, Bhagat Singh, Lala Lajpat Rai, Ashfaq Ulla Khan, and Ram Prasad Bismil. The speech recognizes the contribution of all Indians in achieving independence, and emphasizes the need for continued efforts to safeguard the country's respect. It also mentions the celebration of Independence Day across the country, with the national flag hoisted, national anthem sung, and tribute paid to the martyrs.</s>
# <|user|>
# Can you please list some other national occasions celebrated in India apart from Independence Day?</s>
# <|assistant|>
# Yes, of course! Here are some other national occasions celebrated in India:
#
# 1. Republic Day - January 26
# 2. Gandhi Jayanti - October 2
# 3. Children's Day - November 14
# 4. National Unity Day - October 31
# 5. Teacher's Day - September 5
# 6. Women's Day - March 8
# 7. National Sports Day - August 29
# 8. Martyr's Day - January 30
# 9. Constitution Day - November 26
#
# These are just a few examples, there are many more national and cultural occasions celebrated in different parts of India.</s>

# %% [markdown]
# ### Models - Quantization

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig

model_name = "TinyLlama/TinyLlama-1.1B-intermediate-step-1431k-3T"

# 4-bit quantization configurations - Q in QLoRa
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype="float16",
    bnb_4bit_use_double_quant=True,
)

# Load the model to train on the GPU
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",

    # Leave this out for regular SFT
    quantization_config=bnb_config,
)
model.config.use_cache = False
model.config.pretraining_tp = 1

# Load LLaMa tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=False)
tokenizer.pad_token = "<PAD>"
tokenizer.padding_size = "left"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'transformers.models.arcee.configuration_arcee'
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-16-1316592629.py in <cell line: 0>()
#      13
#      14 # Load the model to train on the GPU
# ---> 15 model = AutoModelForCausalLM.from_pretrained(
#      16     model_name,
#      17     device_map="auto",
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561         elif type(config) in cls._model_mapping.keys():
#     562             model_class = _get_model_class(config, cls._model_mapping)
# --> 563             return model_class.from_pretrained(
#     564                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     565             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in keys(self)
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in <listcomp>(.0)
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in _load_attr_from_module(self, model_type, attr)
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in getattribute_from_module(module, attr)
#     727
#     728     def __getitem__(self, key):
# --> 729         if key in self._extra_content:
#     730             return self._extra_content[key]
#     731         model_type = self._reverse_config_mapping[key.__name__]
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#
# ModuleNotFoundError: Could not import module 'ArceeConfig'. Are this object's requirements defined correctly?
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Configuration

# %%
from peft import LoraConfig, prepare_model_for_kbit_training, get_peft_model

# Prepare LoRA Configuration
peft_config = LoraConfig(
    lora_alpha=32, # LoRA scaling
    lora_dropout=0.1, # Dropout for LoRA layers
    r=64, # Rank
    bias="none",
    task_type="CAUSAL_LM",
    # Layers to target
    target_modules= ['k_proj', 'gate_proj', 'v_proj', 'up_proj', 'q_proj', 'o_proj', 'down_proj']
)

# Prepare model for training
model = prepare_model_for_kbit_training(model)
model = get_peft_model(model, peft_config)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-15-2987969202.py in <cell line: 0>()
# ----> 1 from peft import LoraConfig, prepare_model_for_kbit_training, get_peft_model
#       2
#       3 # Prepare LoRA Configuration
#       4 peft_config = LoraConfig(
#       5     lora_alpha=32, # LoRA scaling
#
# /usr/local/lib/python3.11/dist-packages/peft/__init__.py in <module>
#      20 __version__ = "0.11.1"
#      21
# ---> 22 from .auto import (
#      23     AutoPeftModel,
#      24     AutoPeftModelForCausalLM,
#
# /usr/local/lib/python3.11/dist-packages/peft/auto.py in <module>
#      30
#      31 from .config import PeftConfig
# ---> 32 from .mapping import MODEL_TYPE_TO_PEFT_MODEL_MAPPING
#      33 from .peft_model import (
#      34     PeftModel,
#
# /usr/local/lib/python3.11/dist-packages/peft/mapping.py in <module>
#      20
#      21 from .config import PeftConfig
# ---> 22 from .mixed_model import PeftMixedModel
#      23 from .peft_model import (
#      24     PeftModel,
#
# /usr/local/lib/python3.11/dist-packages/peft/mixed_model.py in <module>
#      24 from transformers.utils import PushToHubMixin
#      25
# ---> 26 from peft.tuners.mixed import COMPATIBLE_TUNER_TYPES
#      27
#      28 from .config import PeftConfig
#
# /usr/local/lib/python3.11/dist-packages/peft/tuners/__init__.py in <module>
#      19
#      20 from .adaption_prompt import AdaptionPromptConfig, AdaptionPromptModel
# ---> 21 from .lora import LoraConfig, LoraModel, LoftQConfig
#      22 from .loha import LoHaConfig, LoHaModel
#      23 from .lokr import LoKrConfig, LoKrModel
#
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/__init__.py in <module>
#      16
#      17 from .config import LoftQConfig, LoraConfig
# ---> 18 from .gptq import QuantLinear
#      19 from .layer import Conv2d, Embedding, Linear, LoraLayer
#      20 from .model import LoraModel
#
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/gptq.py in <module>
#      17 import torch
#      18
# ---> 19 from peft.tuners.lora.layer import LoraLayer
#      20 from peft.tuners.tuners_utils import BaseTunerLayer
#      21 from peft.utils import get_auto_gptq_quant_linear
#
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/layer.py in <module>
#      24 from transformers.pytorch_utils import Conv1D
#      25
# ---> 26 from peft.tuners.tuners_utils import BaseTunerLayer, check_adapters_to_merge
#      27 from peft.utils.integrations import dequantize_module_weight, gather_params_ctx
#      28 from peft.utils.other import transpose
#
# /usr/local/lib/python3.11/dist-packages/peft/tuners/tuners_utils.py in <module>
#      27 from accelerate.utils import named_module_tensors, offload_state_dict
#      28 from torch import nn
# ---> 29 from transformers import PreTrainedModel
#      30 from transformers.pytorch_utils import Conv1D
#      31
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in <module>
#      55     prune_linear_layer,
#      56 )
# ---> 57 from .quantizers import AutoHfQuantizer, HfQuantizer
#      58 from .quantizers.quantizers_utils import get_module_from_name
#      59 from .safetensors_conversion import auto_conversion
#
# /usr/local/lib/python3.11/dist-packages/transformers/quantizers/__init__.py in <module>
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 14 from .auto import AutoHfQuantizer, AutoQuantizationConfig
#      15 from .base import HfQuantizer
#
# /usr/local/lib/python3.11/dist-packages/transformers/quantizers/auto.py in <module>
#      34 from .quantizer_gptq import GptqHfQuantizer
#      35 from .quantizer_hqq import HqqHfQuantizer
# ---> 36 from .quantizer_quanto import QuantoHfQuantizer
#      37
#      38
#
# /usr/local/lib/python3.11/dist-packages/transformers/quantizers/quantizer_quanto.py in <module>
#      24     from ..modeling_utils import PreTrainedModel
#      25
# ---> 26 from ..utils import is_accelerate_available, is_quanto_available, is_torch_available, logging
#      27 from ..utils.quantization_config import QuantoConfig
#      28
#
# ImportError: cannot import name 'is_quanto_available' from 'transformers.utils' (/usr/local/lib/python3.11/dist-packages/transformers/utils/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Training Configuration

# %%
from transformer import TrainingArguments

output_dir = "./results"

# Training arguments
training_arguments = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=2,
    gradient_accumulation_steps=4,
    optim="paged_adamw_32bit",
    learning_rate=2e-4,
    lr_scheduler_type="cosine",
    num_train_epochs=1,
    logging_steps=10,
    fp16=True,
    gradient_checkpointing=True
)
